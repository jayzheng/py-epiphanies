# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit']

# %%
a=300

# %%
_dirn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 _dirn()
#
# NameError: name '_dirn' is not defined

# %%
# %%writefile dirp.py
def _dir(obj='__secret', _CLUTTER=dir()):
    """
    A version of dir that excludes clutter and private names.
    """
    if obj == '__secret':
        names = globals().keys()
    else:
        names = dir(obj)
    return [n for n in names if n not in _CLUTTER and not n.startswith('_')]
    
def _dirn(_CLUTTER=dir()):
    """
    Display the current global namespace, ignoring old names.
    """
    return dict([
        (n, v) for (n, v) in globals().items()
        if not n in _CLUTTER and not n.startswith('_')])
# Out:
# Writing dirp.py

# %%
_dirn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-09acefc6a560> in <module>()
# ----> 1 _dirn()
#
# NameError: name '_dirn' is not defined

# %%
# %load dirp
def _dir(obj='__secret', _CLUTTER=dir()):
    """
    A version of dir that excludes clutter and private names.
    """
    if obj == '__secret':
        names = globals().keys()
    else:
        names = dir(obj)
    return [n for n in names if n not in _CLUTTER and not n.startswith('_')]
    
def _dirn(_CLUTTER=dir()):
    """
    Display the current global namespace, ignoring old names.
    """
    return dict([
        (n, v) for (n, v) in globals().items()
        if not n in _CLUTTER and not n.startswith('_')])

# %%
_dirn()
# Out:
# {}

# %%
a = 300

# %%
_dirn()
# Out:
# {}

# %%
a
# Out:
# 300

# %%
_dirn()
# Out:
# {}

# %%
_dir()
# Out:
# []

# %%
globals().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16'])

# %%
_dirn(_dir())
# Out:
# {'In': ['',
#   'dir()',
#   'a=300',
#   '_dirn()',
#   'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#   '_dirn()',
#   "get_ipython().run_line_magic('load', 'dirp')",
#   '_dirn()',
#   '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#   '_dirn()',
#   'a = 300',
#   '_dirn()',
#   'a',
#   '_dirn()',
#   '_dir()',
#   'globals()',
#   'globals().keys()',
#   '_dirn(_dir())'],
#  'Out': {1: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   9: {},
#   11: {},
#   12: 300,
#   13: {},
#   14: [],
#   15: {'In': ['',
#     'dir()',
#     'a=300',
#     '_dirn()',
#     'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#     '_dirn()',
#     "get_ipython().run_line_magic('load', 'dirp')",
#     '_dirn()',
#     '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_dirn()',
#     'a = 300',
#     '_dirn()',
#     'a',
#     '_dirn()',
#     '_dir()',
#     'globals()',
#     'globals().keys()',
#     '_dirn(_dir())'],
#    'Out': {...},
#    '_': dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17']),
#    '_1': ['In',
#     'Out',
#     '_',
#     '__',
#     '___',
#     '__builtin__',
#     '__builtins__',
#     '__doc__',
#     '__loader__',
#     '__name__',
#     '__package__',
#     '__spec__',
#     '_dh',
#     '_i',
#     '_i1',
#     '_ih',
#     '_ii',
#     '_iii',
#     '_oh',
#     'exit',
#     'get_ipython',
#     'quit'],
#    '_11': {},
#    '_12': 300,
#    '_13': {},
#    '_14': [],
#    '_15': {...},
#    '_16': dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17']),
#    '_9': {},
#    '__': {...},
#    '___': [],
#    '__builtin__': <module 'builtins' (built-in)>,
#    '__builtins__': <module 'builtins' (built-in)>,
#    '__doc__': 'Automatically created module for IPython interactive environment',
#    '__loader__': None,
#    '__name__': '__main__',
#    '__package__': None,
#    '__spec__': None,
#    '_dh': ['/Users/jayzheng/programming/pythonPrjs/epiphonies'],
#    '_dir': <function __main__._dir>,
#    '_dirn': <function __main__._dirn>,
#    '_i': 'globals().keys()',
#    '_i1': 'dir()',
#    '_i10': 'a = 300',
#    '_i11': '_dirn()',
#    '_i12': 'a',
#    '_i13': '_dirn()',
#    '_i14': '_dir()',
#    '_i15': 'globals()',
#    '_i16': 'globals().keys()',
#    '_i17': '_dirn(_dir())',
#    '_i2': 'a=300',
#    '_i3': '_dirn()',
#    '_i4': '%%writefile dirp.py\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_i5': '_dirn()',
#    '_i6': '%load dirp',
#    '_i7': '_dirn()',
#    '_i8': '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_i9': '_dirn()',
#    '_ih': ['',
#     'dir()',
#     'a=300',
#     '_dirn()',
#     'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#     '_dirn()',
#     "get_ipython().run_line_magic('load', 'dirp')",
#     '_dirn()',
#     '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_dirn()',
#     'a = 300',
#     '_dirn()',
#     'a',
#     '_dirn()',
#     '_dir()',
#     'globals()',
#     'globals().keys()',
#     '_dirn(_dir())'],
#    '_ii': 'globals()',
#    '_iii': '_dir()',
#    '_oh': {...},
#    'a': 300,
#    'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#    'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#   16: dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17'])},
#  'a': 300,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>}

# %%
_dirn()
# Out:
# {}

# %%
_dirn(_CLUTTER=dir())
# Out:
# {}

# %%
a
# Out:
# 300

# %%
(n, v) for (n, v) in globals().items()
# Out:
#   File "<ipython-input-21-b047863cb9e5>", line 1
#     (n, v) for (n, v) in globals().items()
#              ^
# SyntaxError: invalid syntax

# %%
c=dict([
        (n, v) for (n, v) in globals().items()
        if not n in _dir() and not n.startswith('_')])

# %%
c
# Out:
# {'In': ['',
#   'dir()',
#   'a=300',
#   '_dirn()',
#   'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#   '_dirn()',
#   "get_ipython().run_line_magic('load', 'dirp')",
#   '_dirn()',
#   '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#   '_dirn()',
#   'a = 300',
#   '_dirn()',
#   'a',
#   '_dirn()',
#   '_dir()',
#   'globals()',
#   'globals().keys()',
#   '_dirn(_dir())',
#   '_dirn()',
#   '_dirn(_CLUTTER=dir())',
#   'a',
#   '(n, v) for (n, v) in globals().items()',
#   "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#   "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#   'c'],
#  'Out': {1: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   9: {},
#   11: {},
#   12: 300,
#   13: {},
#   14: [],
#   15: {'In': ['',
#     'dir()',
#     'a=300',
#     '_dirn()',
#     'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#     '_dirn()',
#     "get_ipython().run_line_magic('load', 'dirp')",
#     '_dirn()',
#     '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_dirn()',
#     'a = 300',
#     '_dirn()',
#     'a',
#     '_dirn()',
#     '_dir()',
#     'globals()',
#     'globals().keys()',
#     '_dirn(_dir())',
#     '_dirn()',
#     '_dirn(_CLUTTER=dir())',
#     'a',
#     '(n, v) for (n, v) in globals().items()',
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#     'c'],
#    'Out': {...},
#    '_': 300,
#    '_1': ['In',
#     'Out',
#     '_',
#     '__',
#     '___',
#     '__builtin__',
#     '__builtins__',
#     '__doc__',
#     '__loader__',
#     '__name__',
#     '__package__',
#     '__spec__',
#     '_dh',
#     '_i',
#     '_i1',
#     '_ih',
#     '_ii',
#     '_iii',
#     '_oh',
#     'exit',
#     'get_ipython',
#     'quit'],
#    '_11': {},
#    '_12': 300,
#    '_13': {},
#    '_14': [],
#    '_15': {...},
#    '_16': dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24']),
#    '_17': {'In': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c'],
#     'Out': {...},
#     'a': 300,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#    '_18': {},
#    '_19': {},
#    '_20': 300,
#    '_9': {},
#    '__': {},
#    '___': {},
#    '__builtin__': <module 'builtins' (built-in)>,
#    '__builtins__': <module 'builtins' (built-in)>,
#    '__doc__': 'Automatically created module for IPython interactive environment',
#    '__loader__': None,
#    '__name__': '__main__',
#    '__package__': None,
#    '__spec__': None,
#    '_dh': ['/Users/jayzheng/programming/pythonPrjs/epiphonies'],
#    '_dir': <function __main__._dir>,
#    '_dirn': <function __main__._dirn>,
#    '_i': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#    '_i1': 'dir()',
#    '_i10': 'a = 300',
#    '_i11': '_dirn()',
#    '_i12': 'a',
#    '_i13': '_dirn()',
#    '_i14': '_dir()',
#    '_i15': 'globals()',
#    '_i16': 'globals().keys()',
#    '_i17': '_dirn(_dir())',
#    '_i18': '_dirn()',
#    '_i19': '_dirn(_CLUTTER=dir())',
#    '_i2': 'a=300',
#    '_i20': 'a',
#    '_i21': '(n, v) for (n, v) in globals().items()',
#    '_i22': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#    '_i23': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#    '_i24': 'c',
#    '_i3': '_dirn()',
#    '_i4': '%%writefile dirp.py\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_i5': '_dirn()',
#    '_i6': '%load dirp',
#    '_i7': '_dirn()',
#    '_i8': '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_i9': '_dirn()',
#    '_ih': ['',
#     'dir()',
#     'a=300',
#     '_dirn()',
#     'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#     '_dirn()',
#     "get_ipython().run_line_magic('load', 'dirp')",
#     '_dirn()',
#     '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_dirn()',
#     'a = 300',
#     '_dirn()',
#     'a',
#     '_dirn()',
#     '_dir()',
#     'globals()',
#     'globals().keys()',
#     '_dirn(_dir())',
#     '_dirn()',
#     '_dirn(_CLUTTER=dir())',
#     'a',
#     '(n, v) for (n, v) in globals().items()',
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#     'c'],
#    '_ii': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#    '_iii': '(n, v) for (n, v) in globals().items()',
#    '_oh': {...},
#    'a': 300,
#    'c': {...},
#    'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#    'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#   16: dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24']),
#   17: {'In': ['',
#     'dir()',
#     'a=300',
#     '_dirn()',
#     'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#     '_dirn()',
#     "get_ipython().run_line_magic('load', 'dirp')",
#     '_dirn()',
#     '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_dirn()',
#     'a = 300',
#     '_dirn()',
#     'a',
#     '_dirn()',
#     '_dir()',
#     'globals()',
#     'globals().keys()',
#     '_dirn(_dir())',
#     '_dirn()',
#     '_dirn(_CLUTTER=dir())',
#     'a',
#     '(n, v) for (n, v) in globals().items()',
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#     "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#     'c'],
#    'Out': {...},
#    'a': 300,
#    'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#    'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#    'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#   18: {},
#   19: {},
#   20: 300},
#  'a': 300,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>}

# %%
_dirn().keys()
# Out:
# dict_keys(['c'])

# %%
_dir()
# Out:
# ['c']

# %%
a=300

# %%
_dirn()
# Out:
# {'c': {'In': ['',
#    'dir()',
#    'a=300',
#    '_dirn()',
#    'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#    '_dirn()',
#    "get_ipython().run_line_magic('load', 'dirp')",
#    '_dirn()',
#    '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_dirn()',
#    'a = 300',
#    '_dirn()',
#    'a',
#    '_dirn()',
#    '_dir()',
#    'globals()',
#    'globals().keys()',
#    '_dirn(_dir())',
#    '_dirn()',
#    '_dirn(_CLUTTER=dir())',
#    'a',
#    '(n, v) for (n, v) in globals().items()',
#    "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#    "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#    'c',
#    '_dirn().keys()',
#    '_dir()',
#    'a=300',
#    '_dirn()'],
#   'Out': {1: ['In',
#     'Out',
#     '_',
#     '__',
#     '___',
#     '__builtin__',
#     '__builtins__',
#     '__doc__',
#     '__loader__',
#     '__name__',
#     '__package__',
#     '__spec__',
#     '_dh',
#     '_i',
#     '_i1',
#     '_ih',
#     '_ii',
#     '_iii',
#     '_oh',
#     'exit',
#     'get_ipython',
#     'quit'],
#    9: {},
#    11: {},
#    12: 300,
#    13: {},
#    14: [],
#    15: {'In': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()'],
#     'Out': {...},
#     '_': ['c'],
#     '_1': ['In',
#      'Out',
#      '_',
#      '__',
#      '___',
#      '__builtin__',
#      '__builtins__',
#      '__doc__',
#      '__loader__',
#      '__name__',
#      '__package__',
#      '__spec__',
#      '_dh',
#      '_i',
#      '_i1',
#      '_ih',
#      '_ii',
#      '_iii',
#      '_oh',
#      'exit',
#      'get_ipython',
#      'quit'],
#     '_11': {},
#     '_12': 300,
#     '_13': {},
#     '_14': [],
#     '_15': {...},
#     '_16': dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24', '_24', '_i25', '_25', '_i26', '_26', '_i27', '_i28']),
#     '_17': {'In': ['',
#       'dir()',
#       'a=300',
#       '_dirn()',
#       'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#       '_dirn()',
#       "get_ipython().run_line_magic('load', 'dirp')",
#       '_dirn()',
#       '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#       '_dirn()',
#       'a = 300',
#       '_dirn()',
#       'a',
#       '_dirn()',
#       '_dir()',
#       'globals()',
#       'globals().keys()',
#       '_dirn(_dir())',
#       '_dirn()',
#       '_dirn(_CLUTTER=dir())',
#       'a',
#       '(n, v) for (n, v) in globals().items()',
#       "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#       "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#       'c',
#       '_dirn().keys()',
#       '_dir()',
#       'a=300',
#       '_dirn()'],
#      'Out': {...},
#      'a': 300,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#     '_18': {},
#     '_19': {},
#     '_20': 300,
#     '_24': {...},
#     '_25': dict_keys(['c']),
#     '_26': ['c'],
#     '_9': {},
#     '__': dict_keys(['c']),
#     '___': {...},
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__loader__': None,
#     '__name__': '__main__',
#     '__package__': None,
#     '__spec__': None,
#     '_dh': ['/Users/jayzheng/programming/pythonPrjs/epiphonies'],
#     '_dir': <function __main__._dir>,
#     '_dirn': <function __main__._dirn>,
#     '_i': 'a=300',
#     '_i1': 'dir()',
#     '_i10': 'a = 300',
#     '_i11': '_dirn()',
#     '_i12': 'a',
#     '_i13': '_dirn()',
#     '_i14': '_dir()',
#     '_i15': 'globals()',
#     '_i16': 'globals().keys()',
#     '_i17': '_dirn(_dir())',
#     '_i18': '_dirn()',
#     '_i19': '_dirn(_CLUTTER=dir())',
#     '_i2': 'a=300',
#     '_i20': 'a',
#     '_i21': '(n, v) for (n, v) in globals().items()',
#     '_i22': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#     '_i23': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#     '_i24': 'c',
#     '_i25': '_dirn().keys()',
#     '_i26': '_dir()',
#     '_i27': 'a=300',
#     '_i28': '_dirn()',
#     '_i3': '_dirn()',
#     '_i4': '%%writefile dirp.py\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_i5': '_dirn()',
#     '_i6': '%load dirp',
#     '_i7': '_dirn()',
#     '_i8': '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_i9': '_dirn()',
#     '_ih': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()'],
#     '_ii': '_dir()',
#     '_iii': '_dirn().keys()',
#     '_oh': {...},
#     'a': 300,
#     'c': {...},
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#    16: dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24', '_24', '_i25', '_25', '_i26', '_26', '_i27', '_i28']),
#    17: {'In': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()'],
#     'Out': {...},
#     'a': 300,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#    18: {},
#    19: {},
#    20: 300,
#    24: {...},
#    25: dict_keys(['c']),
#    26: ['c']},
#   'a': 300,
#   'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#   'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>}}

# %%
_dir()
# Out:
# ['c']

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_24',
#  '_25',
#  '_26',
#  '_28',
#  '_29',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_dir',
#  '_dirn',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'c',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
_dirn()
# Out:
# {'c': {'In': ['',
#    'dir()',
#    'a=300',
#    '_dirn()',
#    'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#    '_dirn()',
#    "get_ipython().run_line_magic('load', 'dirp')",
#    '_dirn()',
#    '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#    '_dirn()',
#    'a = 300',
#    '_dirn()',
#    'a',
#    '_dirn()',
#    '_dir()',
#    'globals()',
#    'globals().keys()',
#    '_dirn(_dir())',
#    '_dirn()',
#    '_dirn(_CLUTTER=dir())',
#    'a',
#    '(n, v) for (n, v) in globals().items()',
#    "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#    "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#    'c',
#    '_dirn().keys()',
#    '_dir()',
#    'a=300',
#    '_dirn()',
#    '_dir()',
#    'dir()',
#    '_dirn()'],
#   'Out': {1: ['In',
#     'Out',
#     '_',
#     '__',
#     '___',
#     '__builtin__',
#     '__builtins__',
#     '__doc__',
#     '__loader__',
#     '__name__',
#     '__package__',
#     '__spec__',
#     '_dh',
#     '_i',
#     '_i1',
#     '_ih',
#     '_ii',
#     '_iii',
#     '_oh',
#     'exit',
#     'get_ipython',
#     'quit'],
#    9: {},
#    11: {},
#    12: 300,
#    13: {},
#    14: [],
#    15: {'In': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()',
#      '_dir()',
#      'dir()',
#      '_dirn()'],
#     'Out': {...},
#     '_': ['In',
#      'Out',
#      '_',
#      '_1',
#      '_11',
#      '_12',
#      '_13',
#      '_14',
#      '_15',
#      '_16',
#      '_17',
#      '_18',
#      '_19',
#      '_20',
#      '_24',
#      '_25',
#      '_26',
#      '_28',
#      '_29',
#      '_9',
#      '__',
#      '___',
#      '__builtin__',
#      '__builtins__',
#      '__doc__',
#      '__loader__',
#      '__name__',
#      '__package__',
#      '__spec__',
#      '_dh',
#      '_dir',
#      '_dirn',
#      '_i',
#      '_i1',
#      '_i10',
#      '_i11',
#      '_i12',
#      '_i13',
#      '_i14',
#      '_i15',
#      '_i16',
#      '_i17',
#      '_i18',
#      '_i19',
#      '_i2',
#      '_i20',
#      '_i21',
#      '_i22',
#      '_i23',
#      '_i24',
#      '_i25',
#      '_i26',
#      '_i27',
#      '_i28',
#      '_i29',
#      '_i3',
#      '_i30',
#      '_i4',
#      '_i5',
#      '_i6',
#      '_i7',
#      '_i8',
#      '_i9',
#      '_ih',
#      '_ii',
#      '_iii',
#      '_oh',
#      'a',
#      'c',
#      'exit',
#      'get_ipython',
#      'quit'],
#     '_1': ['In',
#      'Out',
#      '_',
#      '__',
#      '___',
#      '__builtin__',
#      '__builtins__',
#      '__doc__',
#      '__loader__',
#      '__name__',
#      '__package__',
#      '__spec__',
#      '_dh',
#      '_i',
#      '_i1',
#      '_ih',
#      '_ii',
#      '_iii',
#      '_oh',
#      'exit',
#      'get_ipython',
#      'quit'],
#     '_11': {},
#     '_12': 300,
#     '_13': {},
#     '_14': [],
#     '_15': {...},
#     '_16': dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24', '_24', '_i25', '_25', '_i26', '_26', '_i27', '_i28', '_28', '_i29', '_29', '_i30', '_30', '_i31']),
#     '_17': {'In': ['',
#       'dir()',
#       'a=300',
#       '_dirn()',
#       'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#       '_dirn()',
#       "get_ipython().run_line_magic('load', 'dirp')",
#       '_dirn()',
#       '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#       '_dirn()',
#       'a = 300',
#       '_dirn()',
#       'a',
#       '_dirn()',
#       '_dir()',
#       'globals()',
#       'globals().keys()',
#       '_dirn(_dir())',
#       '_dirn()',
#       '_dirn(_CLUTTER=dir())',
#       'a',
#       '(n, v) for (n, v) in globals().items()',
#       "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#       "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#       'c',
#       '_dirn().keys()',
#       '_dir()',
#       'a=300',
#       '_dirn()',
#       '_dir()',
#       'dir()',
#       '_dirn()'],
#      'Out': {...},
#      'a': 300,
#      'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#      'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#     '_18': {},
#     '_19': {},
#     '_20': 300,
#     '_24': {...},
#     '_25': dict_keys(['c']),
#     '_26': ['c'],
#     '_28': {'c': {...}},
#     '_29': ['c'],
#     '_30': ['In',
#      'Out',
#      '_',
#      '_1',
#      '_11',
#      '_12',
#      '_13',
#      '_14',
#      '_15',
#      '_16',
#      '_17',
#      '_18',
#      '_19',
#      '_20',
#      '_24',
#      '_25',
#      '_26',
#      '_28',
#      '_29',
#      '_9',
#      '__',
#      '___',
#      '__builtin__',
#      '__builtins__',
#      '__doc__',
#      '__loader__',
#      '__name__',
#      '__package__',
#      '__spec__',
#      '_dh',
#      '_dir',
#      '_dirn',
#      '_i',
#      '_i1',
#      '_i10',
#      '_i11',
#      '_i12',
#      '_i13',
#      '_i14',
#      '_i15',
#      '_i16',
#      '_i17',
#      '_i18',
#      '_i19',
#      '_i2',
#      '_i20',
#      '_i21',
#      '_i22',
#      '_i23',
#      '_i24',
#      '_i25',
#      '_i26',
#      '_i27',
#      '_i28',
#      '_i29',
#      '_i3',
#      '_i30',
#      '_i4',
#      '_i5',
#      '_i6',
#      '_i7',
#      '_i8',
#      '_i9',
#      '_ih',
#      '_ii',
#      '_iii',
#      '_oh',
#      'a',
#      'c',
#      'exit',
#      'get_ipython',
#      'quit'],
#     '_9': {},
#     '__': ['c'],
#     '___': {'c': {...}},
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__loader__': None,
#     '__name__': '__main__',
#     '__package__': None,
#     '__spec__': None,
#     '_dh': ['/Users/jayzheng/programming/pythonPrjs/epiphonies'],
#     '_dir': <function __main__._dir>,
#     '_dirn': <function __main__._dirn>,
#     '_i': 'dir()',
#     '_i1': 'dir()',
#     '_i10': 'a = 300',
#     '_i11': '_dirn()',
#     '_i12': 'a',
#     '_i13': '_dirn()',
#     '_i14': '_dir()',
#     '_i15': 'globals()',
#     '_i16': 'globals().keys()',
#     '_i17': '_dirn(_dir())',
#     '_i18': '_dirn()',
#     '_i19': '_dirn(_CLUTTER=dir())',
#     '_i2': 'a=300',
#     '_i20': 'a',
#     '_i21': '(n, v) for (n, v) in globals().items()',
#     '_i22': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#     '_i23': "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#     '_i24': 'c',
#     '_i25': '_dirn().keys()',
#     '_i26': '_dir()',
#     '_i27': 'a=300',
#     '_i28': '_dirn()',
#     '_i29': '_dir()',
#     '_i3': '_dirn()',
#     '_i30': 'dir()',
#     '_i31': '_dirn()',
#     '_i4': '%%writefile dirp.py\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_i5': '_dirn()',
#     '_i6': '%load dirp',
#     '_i7': '_dirn()',
#     '_i8': '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#     '_i9': '_dirn()',
#     '_ih': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()',
#      '_dir()',
#      'dir()',
#      '_dirn()'],
#     '_ii': '_dir()',
#     '_iii': '_dirn()',
#     '_oh': {...},
#     'a': 300,
#     'c': {...},
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#    16: dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_1', '_i2', 'a', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_dir', '_dirn', '_i9', '_9', '_i10', '_i11', '_11', '_i12', '_12', '_i13', '_13', '_i14', '_14', '_i15', '_15', '_i16', '_16', '_i17', '_17', '_i18', '_18', '_i19', '_19', '_i20', '_20', '_i21', '_i22', '_i23', 'c', '_i24', '_24', '_i25', '_25', '_i26', '_26', '_i27', '_i28', '_28', '_i29', '_29', '_i30', '_30', '_i31']),
#    17: {'In': ['',
#      'dir()',
#      'a=300',
#      '_dirn()',
#      'get_ipython().run_cell_magic(\'writefile\', \'dirp.py\', \'def _dir(obj=\\\'__secret\\\', _CLUTTER=dir()):\\n    """\\n    A version of dir that excludes clutter and private names.\\n    """\\n    if obj == \\\'__secret\\\':\\n        names = globals().keys()\\n    else:\\n        names = dir(obj)\\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\\\'_\\\')]\\n    \\ndef _dirn(_CLUTTER=dir()):\\n    """\\n    Display the current global namespace, ignoring old names.\\n    """\\n    return dict([\\n        (n, v) for (n, v) in globals().items()\\n        if not n in _CLUTTER and not n.startswith(\\\'_\\\')])\')',
#      '_dirn()',
#      "get_ipython().run_line_magic('load', 'dirp')",
#      '_dirn()',
#      '# %load dirp\ndef _dir(obj=\'__secret\', _CLUTTER=dir()):\n    """\n    A version of dir that excludes clutter and private names.\n    """\n    if obj == \'__secret\':\n        names = globals().keys()\n    else:\n        names = dir(obj)\n    return [n for n in names if n not in _CLUTTER and not n.startswith(\'_\')]\n    \ndef _dirn(_CLUTTER=dir()):\n    """\n    Display the current global namespace, ignoring old names.\n    """\n    return dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith(\'_\')])',
#      '_dirn()',
#      'a = 300',
#      '_dirn()',
#      'a',
#      '_dirn()',
#      '_dir()',
#      'globals()',
#      'globals().keys()',
#      '_dirn(_dir())',
#      '_dirn()',
#      '_dirn(_CLUTTER=dir())',
#      'a',
#      '(n, v) for (n, v) in globals().items()',
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _CLUTTER and not n.startswith('_')])",
#      "c=dict([\n        (n, v) for (n, v) in globals().items()\n        if not n in _dir() and not n.startswith('_')])",
#      'c',
#      '_dirn().keys()',
#      '_dir()',
#      'a=300',
#      '_dirn()',
#      '_dir()',
#      'dir()',
#      '_dirn()'],
#     'Out': {...},
#     'a': 300,
#     'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>},
#    18: {},
#    19: {},
#    20: 300,
#    24: {...},
#    25: dict_keys(['c']),
#    26: ['c'],
#    28: {'c': {...}},
#    29: ['c'],
#    30: ['In',
#     'Out',
#     '_',
#     '_1',
#     '_11',
#     '_12',
#     '_13',
#     '_14',
#     '_15',
#     '_16',
#     '_17',
#     '_18',
#     '_19',
#     '_20',
#     '_24',
#     '_25',
#     '_26',
#     '_28',
#     '_29',
#     '_9',
#     '__',
#     '___',
#     '__builtin__',
#     '__builtins__',
#     '__doc__',
#     '__loader__',
#     '__name__',
#     '__package__',
#     '__spec__',
#     '_dh',
#     '_dir',
#     '_dirn',
#     '_i',
#     '_i1',
#     '_i10',
#     '_i11',
#     '_i12',
#     '_i13',
#     '_i14',
#     '_i15',
#     '_i16',
#     '_i17',
#     '_i18',
#     '_i19',
#     '_i2',
#     '_i20',
#     '_i21',
#     '_i22',
#     '_i23',
#     '_i24',
#     '_i25',
#     '_i26',
#     '_i27',
#     '_i28',
#     '_i29',
#     '_i3',
#     '_i30',
#     '_i4',
#     '_i5',
#     '_i6',
#     '_i7',
#     '_i8',
#     '_i9',
#     '_ih',
#     '_ii',
#     '_iii',
#     '_oh',
#     'a',
#     'c',
#     'exit',
#     'get_ipython',
#     'quit']},
#   'a': 300,
#   'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10d163fd0>>,
#   'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10d163550>}}

# %%
del c

# %%
_dirn()
# Out:
# {}

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'all',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']
